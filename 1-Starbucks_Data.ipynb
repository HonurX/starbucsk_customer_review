# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
df= pd.read_csv("Starbucks_satisfactory_survey.csv")

# %%
df
# Out:
#                         Timestamp 1. Your Gender    2. Your Age  \
# 0    2019/10/01 12:38:43 PM GMT+8         Female  From 20 to 29
# 1    2019/10/01 12:38:54 PM GMT+8         Female  From 20 to 29
# 2    2019/10/01 12:38:56 PM GMT+8           Male  From 20 to 29
# 3    2019/10/01 12:39:08 PM GMT+8         Female  From 20 to 29
# 4    2019/10/01 12:39:20 PM GMT+8           Male  From 20 to 29
# ..                            ...            ...            ...
# 117  2019/10/04 12:24:26 AM GMT+8           Male   40 and above
# 118   2019/10/04 9:30:09 AM GMT+8           Male  From 20 to 29
# 119   2019/10/04 1:46:07 PM GMT+8           Male  From 20 to 29
# 120  2019/10/05 11:01:14 AM GMT+8         Female  From 20 to 29
# 121   2019/10/05 4:57:22 PM GMT+8           Male  From 20 to 29
#
#     3. Are you currently....? 4. What is your annual income?  \
# 0                     Student             Less than RM25,000
# 1                     Student             Less than RM25,000
# ...

# %%
df["Timestamp"] = df["Timestamp"].astype(str)
df["Timestamp"] = pd.to_datetime(df["Timestamp"])
# Out:
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_13068\2247550655.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               122 non-null    datetime64[ns, UTC-08:00]
#  1   1. Your Gender                                                                                                          122 non-null    object
#  2   2. Your Age                                                                                                             122 non-null    object
# ...

# %%
df.describe()
# Out:
#        12. How would you rate the quality of Starbucks compared to other brands (Coffee Bean, Old Town White Coffee..) to be:  \
# count                                         122.000000
# mean                                            3.663934
# std                                             0.941343
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        13. How would you rate the price range at Starbucks?  \
# count                                         122.000000
# mean                                            2.893443
# std                                             1.081836
# min                                             1.000000
# 25%                                             2.000000
# ...

# %%
df.sample()
# Out:
#                    Timestamp 1. Your Gender    2. Your Age  \
# 27 2019-10-01 13:33:54-08:00           Male  From 20 to 29
#
#    3. Are you currently....? 4. What is your annual income?  \
# 27             Self-employed             Less than RM25,000
#
#    5. How often do you visit Starbucks?  \
# 27                              Monthly
#
#    6. How do you usually enjoy Starbucks?  \
# 27                              Take away
#
#    7. How much time do you normally  spend during your visit?  \
# 27                                   Below 30 minutes
#
#    8. The nearest Starbucks's outlet to you is...?  \
# 27                                   more than 3km
#
#    9. Do you have Starbucks membership card?  ...  \
# 27                                        No  ...
#
#    11. On average, how much would you spend at Starbucks per visit?  \
# 27                                 Around RM20 - RM40
#
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    1
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    1
# ...

# %%
df["19. How do you come to hear of promotions at Starbucks? Check all that apply."]=df["19. How do you come to hear of promotions at Starbucks? Check all that apply."].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    1
# ...

# %%
df[df["6. How do you usually enjoy Starbucks?"].isnull()].index
# Out:
# Index([81], dtype='int64')

# %%
df.iloc[81]
# Out:
# Timestamp                                                                                                                 2019-10-03 09:11:28-08:00
# 1. Your Gender                                                                                                                                 Male
# 2. Your Age                                                                                                                           From 20 to 29
# 3. Are you currently....?                                                                                                                  Employed
# 4. What is your annual income?                                                                                                   Less than RM25,000
# 5. How often do you visit Starbucks?                                                                                                          Never
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="most_frequent")


df["6. How do you usually enjoy Starbucks?"] = imputer.fit_transform(
    df[["6. How do you usually enjoy Starbucks?"]]
).ravel()

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    0
# ...

# %%
df["3. Are you currently....?"].value_counts().plot(kind="bar" , color="brown")
# Out:
# <Axes: xlabel='3. Are you currently....?'>

# %%
df["4. What is your annual income?"].value_counts().plot(kind="bar" , color="pink")
# Out:
# <Axes: xlabel='4. What is your annual income?'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               122 non-null    datetime64[ns, UTC-08:00]
#  1   1. Your Gender                                                                                                          122 non-null    object
#  2   2. Your Age                                                                                                             122 non-null    object
# ...

# %%
df_numeric= df.select_dtypes(include=np.number)

# %%
df_numeric
# Out:
#      12. How would you rate the quality of Starbucks compared to other brands (Coffee Bean, Old Town White Coffee..) to be:  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 117                                                  3
# 118                                                  5
# 119                                                  3
# 120                                                  4
# 121                                                  1
#
#      13. How would you rate the price range at Starbucks?  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# ...

# %%
df_numeric.describe()
# Out:
#        12. How would you rate the quality of Starbucks compared to other brands (Coffee Bean, Old Town White Coffee..) to be:  \
# count                                         122.000000
# mean                                            3.663934
# std                                             0.941343
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        13. How would you rate the price range at Starbucks?  \
# count                                         122.000000
# mean                                            2.893443
# std                                             1.081836
# min                                             1.000000
# 25%                                             2.000000
# ...

# %%
df["1. Your Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='1. Your Gender'>

# %%
import os

# %%
for col in df:
    plt.figure(figsize=(15,5))
    sb.histplot(data=df , x=col)
    plt.show()

# %%
labels = df["1. Your Gender"].unique()
sizes = df['1. Your Gender'].value_counts()

fig = plt.figure(figsize=(10,6))
ax= fig.add_subplot()


ax.pie(sizes , labels=labels , autopct="%1.1f%%" )
plt.show()

# %%
labels = df["20. Will you continue buying at Starbucks?"].unique()
sizes = df['20. Will you continue buying at Starbucks?'].value_counts()

fig = plt.figure(figsize=(10,6))
ax= fig.add_subplot()


ax.pie(sizes , labels=labels , autopct="%1.1f%%" )
plt.title("Will you continue buying at Starbucks?")
plt.show()

# %%
df.groupby("1. Your Gender").agg({"9. Do you have Starbucks membership card?": ["count"] }).plot(kind="bar" , color=["blue" ,"red"])

plt.title("Gender Membership Counts")
plt.figure(figsize=(14,9))

# %%
gender_membership = df.groupby("1. Your Gender")["9. Do you have Starbucks membership card?"].value_counts().unstack().plot(kind="bar", figsize=(14,6))

plt.title("Gender Membership")
plt.xlabel("Gender")
plt.ylabel("Count")


plt.show()


##very nice view of data

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    0
# ...

# %%
df["19. How do you come to hear of promotions at Starbucks? Check all that apply."]
# Out:
# 0      Starbucks Website/Apps;Social Media;Emails;Dea...
# 1                         Social Media;In Store displays
# 2                           In Store displays;Billboards
# 3                      Through friends and word of mouth
# 4                    Starbucks Website/Apps;Social Media
#                              ...
# 117                  Starbucks Website/Apps;Social Media
# 118    Starbucks Website/Apps;Social Media;Emails;Dea...
# 119    Social Media;Through friends and word of mouth...
# 120    Social Media;Through friends and word of mouth...
# 121                                    In Store displays
# Name: 19. How do you come to hear of promotions at Starbucks? Check all that apply., Length: 122, dtype: object

# %%
df
# Out:
#                     Timestamp 1. Your Gender    2. Your Age  \
# 0   2019-10-01 12:38:43-08:00         Female  From 20 to 29
# 1   2019-10-01 12:38:54-08:00         Female  From 20 to 29
# 2   2019-10-01 12:38:56-08:00           Male  From 20 to 29
# 3   2019-10-01 12:39:08-08:00         Female  From 20 to 29
# 4   2019-10-01 12:39:20-08:00           Male  From 20 to 29
# ..                        ...            ...            ...
# 117 2019-10-04 00:24:26-08:00           Male   40 and above
# 118 2019-10-04 09:30:09-08:00           Male  From 20 to 29
# 119 2019-10-04 13:46:07-08:00           Male  From 20 to 29
# 120 2019-10-05 11:01:14-08:00         Female  From 20 to 29
# 121 2019-10-05 16:57:22-08:00           Male  From 20 to 29
#
#     3. Are you currently....? 4. What is your annual income?  \
# 0                     Student             Less than RM25,000
# 1                     Student             Less than RM25,000
# ...

# %%
##df = df[~df["6. How do you usually enjoy Starbucks?"].str.lower().str.contains("never | I dont like coffee")]  ## this helps to remove lower case string and str contains certain names

# %%
##df = df[~df["6. How do you usually enjoy Starbucks?"].str.contains("I dont like coffee")] 

##but it will unbalance the model with lost rows , not healty for modeling

## this helps to remove lower case string and str contains certain names

# %%
most_frequent = df["6. How do you usually enjoy Starbucks?"].mode()[0]

# %%
most_frequent = df["6. How do you usually enjoy Starbucks?"].mode()[0]  ## this will help most frequent string to replace non wanted entries , it woint affect data set

df["6. How do you usually enjoy Starbucks?"] = df["6. How do you usually enjoy Starbucks?"].replace(["Never buy" , "never" , "Never " , "Never" , "I dont like coffee"] ,most_frequent)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               122 non-null    datetime64[ns, UTC-08:00]
#  1   1. Your Gender                                                                                                          122 non-null    object
#  2   2. Your Age                                                                                                             122 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df["6. How do you usually enjoy Starbucks?"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='6. How do you usually enjoy Starbucks?'>

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                                                 0
# 1. Your Gender                                                                                                            0
# 2. Your Age                                                                                                               0
# 3. Are you currently....?                                                                                                 0
# 4. What is your annual income?                                                                                            0
# 5. How often do you visit Starbucks?                                                                                      0
# 6. How do you usually enjoy Starbucks?                                                                                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               122 non-null    datetime64[ns, UTC-08:00]
#  1   1. Your Gender                                                                                                          122 non-null    object
#  2   2. Your Age                                                                                                             122 non-null    object
# ...

# %%
df["2. Your Age"] = le.fit_transform(df["2. Your Age"]).astype(int)

# %%
df["10. What do you most frequently purchase at Starbucks?"] = le.fit_transform(df["10. What do you most frequently purchase at Starbucks?"])

# %%
df["11. On average, how much would you spend at Starbucks per visit?"] = le.fit_transform(df["11. On average, how much would you spend at Starbucks per visit?"])

# %%
df["19. How do you come to hear of promotions at Starbucks? Check all that apply."] = le.fit_transform(df["19. How do you come to hear of promotions at Starbucks? Check all that apply."])

# %%
df["7. How much time do you normally  spend during your visit?"] = le.fit_transform(df["7. How much time do you normally  spend during your visit?"])

# %%
df["8. The nearest Starbucks's outlet to you is...?"] = le.fit_transform(df["8. The nearest Starbucks's outlet to you is...?"])

# %%
df["9. Do you have Starbucks membership card?"] = le.fit_transform(df["9. Do you have Starbucks membership card?"])

# %%
df["20. Will you continue buying at Starbucks?"] = le.fit_transform(df["20. Will you continue buying at Starbucks?"])

# %%
df["1. Your Gender"] = le.fit_transform(df["1. Your Gender"])

# %%
df["3. Are you currently....?"] = le.fit_transform(df["3. Are you currently....?"])

# %%
df["4. What is your annual income?"] = le.fit_transform(df["4. What is your annual income?"])

# %%
df["5. How often do you visit Starbucks?"] = le.fit_transform(df["5. How often do you visit Starbucks?"])

# %%
df["6. How do you usually enjoy Starbucks?"] = le.fit_transform(df["6. How do you usually enjoy Starbucks?"])

# %%
df_numeric
# Out:
#      12. How would you rate the quality of Starbucks compared to other brands (Coffee Bean, Old Town White Coffee..) to be:  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 117                                                  3
# 118                                                  5
# 119                                                  3
# 120                                                  4
# 121                                                  1
#
#      13. How would you rate the price range at Starbucks?  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 21 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                               122 non-null    datetime64[ns, UTC-08:00]
#  1   1. Your Gender                                                                                                          122 non-null    int32
#  2   2. Your Age                                                                                                             122 non-null    int32
# ...

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(19,12))
sb.heatmap(correlation , annot=True , cmap="coolwarm")
plt.show()

# %%
df.describe()
# Out:
#        1. Your Gender  2. Your Age  3. Are you currently....?  \
# count      122.000000   122.000000                 122.000000
# mean         0.467213     1.918033                   1.327869
# std          0.500981     0.687433                   1.387325
# min          0.000000     0.000000                   0.000000
# 25%          0.000000     2.000000                   0.000000
# 50%          0.000000     2.000000                   0.500000
# 75%          1.000000     2.000000                   3.000000
# max          1.000000     3.000000                   3.000000
#
#        4. What is your annual income?  5. How often do you visit Starbucks?  \
# count                      122.000000                             122.00000
# mean                         1.270492                               2.52459
# std                          1.621329                               0.96392
# min                          0.000000                               0.00000
# ...

# %%
y = df["20. Will you continue buying at Starbucks?"].values
x = df.drop("20. Will you continue buying at Starbucks?" , axis =1 ).values

# %%
y.shape
# Out:
# (122,)

# %%
x.shape
# Out:
# (122, 20)

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test  = train_test_split(x, y , random_state=34 , test_size=0.1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[173], line 3
#       1 scaler = MinMaxScaler()
# ----> 3 x_train = scaler.fit_transform(x_train)
#       4 x_test = scaler.transform(x_test)
#
# File ~\anaconda_envs\test-env\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
x_train.shape

# %%
y_test.shape

# %%
y_train.shape

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation , Dropout
from sklearn.metrics import classification_report , confusion_matrix

# %%
modelTensor = Sequential()

# %%
modelTensor.add(Dense(19, activation="relu"))
modelTensor.add(Dense(10, activation="relu"))
modelTensor.add(Dense(10, activation="relu"))
modelTensor.add(Dense(10, activation="relu"))
modelTensor.add(Dense(2,activation="relu"))

modelTensor.add(Dense(1,activation="sigmoid"))

modelTensor.compile(optimizer="adam" , loss = "binary_crossentropy" , metrics=(["accuracy"]) )

# %%
modelTensor.fit(x=x_train , y=y_train  , verbose=1 , epochs=150, validation_data=(x_test , y_test))

# %%
modelLoss = pd.DataFrame(modelTensor.history.history)

# %%
modelLoss.plot()

# %%
yPred= modelTensor.predict(x_test)

# %%
yPred

# %%
predicted_classes = (yPred > 0.6).astype(int)

# %%
predicted_classes

# %%
print(classification_report(y_test, predicted_classes))

# %%
print(confusion_matrix(y_test , predicted_classes))
